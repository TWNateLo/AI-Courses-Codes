# %%
import numpy as np 
import matplotlib.pyplot as plt
listx = np.random.randint(100,size =500)
listy=  np.random.randint(100,size= 500)

plt.xlim(0,100)
plt.ylim(0,100)
# s -> size, alpha -> transparency
plt.scatter(listx,listy,color='red',marker='o',s=40,alpha=0.8)
plt.show()
